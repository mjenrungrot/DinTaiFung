# %%
import IPython.display as ipd
import torch
import matplotlib.pyplot as plt
import scipy.io
import numpy as np
import torch.nn.functional as F
import librosa.output
from matplotlib import cm
import matplotlib
import mir_eval
from sdr import GetSDR, compute_measures
# Out:
# /homes/grail/vjayaram/.local/lib/python3.6/site-packages/pkg_resources/__init__.py:1908: UserWarning: /homes/grail/vjayaram/.local/lib/python3.6/site-packages/._wrapt-1.11.2-py3.6.egg-info could not be properly decoded in UTF-8
#   warnings.warn(msg)
# /homes/grail/vjayaram/.local/lib/python3.6/site-packages/pkg_resources/__init__.py:1908: UserWarning: /homes/grail/vjayaram/.local/lib/python3.6/site-packages/._termcolor-1.1.0-py3.6.egg-info could not be properly decoded in UTF-8
#   warnings.warn(msg)
# /homes/grail/vjayaram/.local/lib/python3.6/site-packages/pkg_resources/__init__.py:1908: UserWarning: /homes/grail/vjayaram/.local/lib/python3.6/site-packages/._librosa-0.7.0-py3.6.egg-info could not be properly decoded in UTF-8
#   warnings.warn(msg)
# /homes/grail/vjayaram/.local/lib/python3.6/site-packages/pkg_resources/__init__.py:1908: UserWarning: /homes/grail/vjayaram/.local/lib/python3.6/site-packages/._audioread-2.1.8-py3.6.egg-info could not be properly decoded in UTF-8
#   warnings.warn(msg)
# /homes/grail/vjayaram/.local/lib/python3.6/site-packages/pkg_resources/__init__.py:1908: UserWarning: /homes/grail/vjayaram/.local/lib/python3.6/site-packages/._absl_py-0.8.0-py3.6.egg-info could not be properly decoded in UTF-8
#   warnings.warn(msg)
# /homes/grail/vjayaram/.local/lib/python3.6/site-packages/pkg_resources/__init__.py:1908: UserWarning: /homes/grail/vjayaram/.local/lib/python3.6/site-packages/._wrapt-1.11.2-py3.6.egg-info could not be properly decoded in UTF-8
#   warnings.warn(msg)
# /homes/grail/vjayaram/.local/lib/python3.6/site-packages/pkg_resources/__init__.py:1908: UserWarning: /homes/grail/vjayaram/.local/lib/python3.6/site-packages/._termcolor-1.1.0-py3.6.egg-info could not be properly decoded in UTF-8
#   warnings.warn(msg)
# /homes/grail/vjayaram/.local/lib/python3.6/site-packages/pkg_resources/__init__.py:1908: UserWarning: /homes/grail/vjayaram/.local/lib/python3.6/site-packages/._librosa-0.7.0-py3.6.egg-info could not be properly decoded in UTF-8
#   warnings.warn(msg)
# /homes/grail/vjayaram/.local/lib/python3.6/site-packages/pkg_resources/__init__.py:1908: UserWarning: /homes/grail/vjayaram/.local/lib/python3.6/site-packages/._audioread-2.1.8-py3.6.egg-info could not be properly decoded in UTF-8
#   warnings.warn(msg)
# /homes/grail/vjayaram/.local/lib/python3.6/site-packages/pkg_resources/__init__.py:1908: UserWarning: /homes/grail/vjayaram/.local/lib/python3.6/site-packages/._absl_py-0.8.0-py3.6.egg-info could not be properly decoded in UTF-8
#   warnings.warn(msg)

# %%
matplotlib.style.use('ggplot')
np.random.seed(123)
SAMPLE_RATE=22050

# %%
from data import SpatialAudioDatasetWaveform, RealDataset, MixedDataset
from network import center_trim, Demucs

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %%
# fg_file = '/projects/grail/vjayaram/DinTaiFung/dataset_generators/harry_potter_10min_16b.wav'
#data_dir_real = '/projects/grail/audiovisual/datasets/DinTaiFung/2mics_real_vctk_recorded/test/'
#data_dir = '/projects/grail/audiovisual/datasets/DinTaiFung/2mics_real_samples_synthetic_composite/train/'
#data_test = RealDataset(data_dir_real, sr=SAMPLE_RATE, short_data=True)

data_dir_synth = "/projects/grail/audiovisual/datasets/DinTaiFung/pyroom_6mics_multiplevoices/test"
data_test = SpatialAudioDatasetWaveform(data_dir_synth, n_mics=6, sr=SAMPLE_RATE,
                                        target_fg_std=None, target_bg_std=None,
                                        angular_specificity_idx=4,
                                       requires_n_voices=4)

#data_test = MixedDataset(data_dir_synth, data_dir_real, 1000, sr=SAMPLE_RATE, perturb_prob=0.0, short_data=True)
device = torch.device('cuda:0')

# %%
kwargs = {
    'num_workers': 0,
    'pin_memory': True
}

# %%
import torch
print(torch.rand(1, device="cuda"))
# Out:
# tensor([0.8792], device='cuda:0')

# %%
test_loader = torch.utils.data.DataLoader(data_test,
                                          batch_size=4,
                                          shuffle=False,
                                          **kwargs)

# %%
# %ls checkpoints/5degrees_6mics/
# Out:
# 5degrees_6mics_0.pt   5degrees_6mics_21.pt  5degrees_6mics_33.pt
# 5degrees_6mics_10.pt  5degrees_6mics_22.pt  5degrees_6mics_34.pt
# 5degrees_6mics_11.pt  5degrees_6mics_23.pt  5degrees_6mics_35.pt
# 5degrees_6mics_12.pt  5degrees_6mics_24.pt  5degrees_6mics_36.pt
# 5degrees_6mics_13.pt  5degrees_6mics_25.pt  5degrees_6mics_3.pt
# 5degrees_6mics_14.pt  5degrees_6mics_26.pt  5degrees_6mics_4.pt
# 5degrees_6mics_15.pt  5degrees_6mics_27.pt  5degrees_6mics_5.pt
# 5degrees_6mics_16.pt  5degrees_6mics_28.pt  5degrees_6mics_6.pt
# 5degrees_6mics_17.pt  5degrees_6mics_29.pt  5degrees_6mics_7.pt
# 5degrees_6mics_18.pt  5degrees_6mics_2.pt   5degrees_6mics_8.pt
# 5degrees_6mics_19.pt  5degrees_6mics_30.pt  5degrees_6mics_9.pt
# 5degrees_6mics_1.pt   5degrees_6mics_31.pt
# 5degrees_6mics_20.pt  5degrees_6mics_32.pt

# %%
model = Demucs(sources=2, n_audio_channels=6)

# %%
#model.load_state_dict(torch.load('checkpoints/90degrees_6mics/90degrees_6mics_7.pt'))
#model.load_state_dict(torch.load('checkpoints/45degrees_6mics/45degrees_6mics_0.pt'))
#model.load_state_dict(torch.load('checkpoints/22degrees_6mics/22degrees_6mics_3.pt'))
#model.load_state_dict(torch.load('checkpoints/11degrees_6mics/11degrees_6mics_11.pt'))
model.load_state_dict(torch.load('checkpoints/5degrees_6mics/5degrees_6mics_36.pt'))

#model.load_state_dict(torch.load('checkpoints/vctk_real_recording_22050_mixed/vctk_real_recording_22050_mixed_2.pt'))
#model.load_state_dict(torch.load('checkpoints/vctk_real_recording_3200_new_mics/vctk_real_recording_3200_new_mics_24.pt'))
#model.load_state_dict(torch.load('checkpoints/pyroom_synthetic_3voices_22050/pyroom_synthetic_3voices_22050_22.pt'))
# model.load_state_dict(torch.load('checkpoints/vctk_real_recording_22050_multiplevoices/vctk_real_recording_22050_multiplevoices_7.pt'))
model.train = False
model.to(device)
# Out:
# Demucs(
#   (encoder): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(6, 64, kernel_size=(8,), stride=(4,))
#       (1): ReLU()
#       (2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (3): GLU(dim=1)
#     )
#     (1): Sequential(
#       (0): Conv1d(64, 128, kernel_size=(8,), stride=(4,))
#       (1): ReLU()
#       (2): Conv1d(128, 256, kernel_size=(1,), stride=(1,))
#       (3): GLU(dim=1)
#     )
#     (2): Sequential(
#       (0): Conv1d(128, 256, kernel_size=(8,), stride=(4,))
#       (1): ReLU()
#       (2): Conv1d(256, 512, kernel_size=(1,), stride=(1,))
#       (3): GLU(dim=1)
#     )
#     (3): Sequential(
#       (0): Conv1d(256, 512, kernel_size=(8,), stride=(4,))
#       (1): ReLU()
#       (2): Conv1d(512, 1024, kernel_size=(1,), stride=(1,))
#       (3): GLU(dim=1)
#     )
#     (4): Sequential(
#       (0): Conv1d(512, 1024, kernel_size=(8,), stride=(4,))
#       (1): ReLU()
#       (2): Conv1d(1024, 2048, kernel_size=(1,), stride=(1,))
#       (3): GLU(dim=1)
#     )
#     (5): Sequential(
#       (0): Conv1d(1024, 2048, kernel_size=(8,), stride=(4,))
#       (1): ReLU()
#       (2): Conv1d(2048, 4096, kernel_size=(1,), stride=(1,))
#       (3): GLU(dim=1)
#     )
#   )
#   (decoder): ModuleList(
#     (0): Sequential(
#       (0): Conv1d(2048, 4096, kernel_size=(3,), stride=(1,))
#       (1): GLU(dim=1)
#       (2): ConvTranspose1d(2048, 1024, kernel_size=(8,), stride=(4,))
#       (3): ReLU()
#     )
#     (1): Sequential(
#       (0): Conv1d(1024, 2048, kernel_size=(3,), stride=(1,))
#       (1): GLU(dim=1)
#       (2): ConvTranspose1d(1024, 512, kernel_size=(8,), stride=(4,))
#       (3): ReLU()
#     )
#     (2): Sequential(
#       (0): Conv1d(512, 1024, kernel_size=(3,), stride=(1,))
#       (1): GLU(dim=1)
#       (2): ConvTranspose1d(512, 256, kernel_size=(8,), stride=(4,))
#       (3): ReLU()
#     )
#     (3): Sequential(
#       (0): Conv1d(256, 512, kernel_size=(3,), stride=(1,))
#       (1): GLU(dim=1)
#       (2): ConvTranspose1d(256, 128, kernel_size=(8,), stride=(4,))
#       (3): ReLU()
#     )
#     (4): Sequential(
#       (0): Conv1d(128, 256, kernel_size=(3,), stride=(1,))
#       (1): GLU(dim=1)
#       (2): ConvTranspose1d(128, 64, kernel_size=(8,), stride=(4,))
#       (3): ReLU()
#     )
#     (5): Sequential(
#       (0): Conv1d(64, 128, kernel_size=(3,), stride=(1,))
#       (1): GLU(dim=1)
#       (2): ConvTranspose1d(64, 12, kernel_size=(8,), stride=(4,))
#     )
#   )
#   (loc_decoder): ModuleList(
#     (0): Sequential(
#       (0): ConvTranspose1d(3, 3, kernel_size=(8,), stride=(4,))
#       (1): ReLU()
#     )
#     (1): Sequential(
#       (0): ConvTranspose1d(3, 3, kernel_size=(8,), stride=(4,))
#       (1): ReLU()
#     )
#     (2): Sequential(
#       (0): ConvTranspose1d(3, 3, kernel_size=(8,), stride=(4,))
#       (1): ReLU()
#     )
#     (3): Sequential(
#       (0): ConvTranspose1d(3, 3, kernel_size=(8,), stride=(4,))
#       (1): ReLU()
#     )
#     (4): Sequential(
#       (0): ConvTranspose1d(3, 3, kernel_size=(8,), stride=(4,))
#       (1): ReLU()
#     )
#     (5): Sequential(
#       (0): ConvTranspose1d(3, 6, kernel_size=(8,), stride=(4,))
#     )
#   )
#   (lstm): LSTM(2048, 2048, num_layers=2, bidirectional=True)
#   (lstm_linear): Linear(in_features=4096, out_features=2048, bias=True)
#   (loc_prediction): Linear(in_features=4096, out_features=3, bias=True)
# )

# %%
np.random.seed(123)
with torch.no_grad():
    #for batch_idx, (type_name, (data, label_voice_signals)) in enumerate(test_loader):
    for batch_idx, (data, label_voice_signals, locs_voice, target_pos) in enumerate(test_loader):
        print(batch_idx)
        if batch_idx != 0: continue
#         data = label_bg_signals[:,0,:,:]
        data = data.to(device)
        label_voice_signals = label_voice_signals.to(device)

        # Normalize input
        data = (data * 2**15).round() / 2**15
        ref = data.mean(1)  # Average across the n microphones
        means = ref.mean(1).unsqueeze(1).unsqueeze(2)
        stds = ref.std(1).unsqueeze(1).unsqueeze(2)
        data_transformed = (data - means) / stds

        # Run through the model
        valid_length = model.valid_length(data_transformed.shape[-1])
        delta = valid_length - data_transformed.shape[-1]
        padded = F.pad(data_transformed, (delta // 2, delta - delta // 2))

        output_signal, output_locs = model(padded)
        output_signal = center_trim(output_signal, data_transformed)
        output_locs = center_trim(output_locs, data_transformed)
        
        output_signal = output_signal * ref.std() + ref.mean()
        output_voices = output_signal[:, 0]

        break
# Out:
# /projects/grail/audiovisual/datasets/DinTaiFung/pyroom_6mics_multiplevoices/test/00002
# /projects/grail/audiovisual/datasets/DinTaiFung/pyroom_6mics_multiplevoices/test/00003
# /projects/grail/audiovisual/datasets/DinTaiFung/pyroom_6mics_multiplevoices/test/00004
# /projects/grail/audiovisual/datasets/DinTaiFung/pyroom_6mics_multiplevoices/test/00008
# 0

# %%
data_transformed[0].mean(0).std()
# Out:
# tensor(1., device='cuda:0')

# %%
print(output_voices.shape)
print(label_voice_signals.shape)
for i in range(32):
    print("----------------")
    #print(type_name[i])
    print("idx {} loss {}".format(i, model.voice_loss(output_voices[i], label_voice_signals[i, 0])[0]))
    print(label_voice_signals[i,:,:].cpu().detach().numpy().std())
    print(output_voices[i,:,:].cpu().detach().numpy().std())
    
    #import pdb
    #pdb.set_trace()
    #input_sdr, input_sir, input_sar, input_perm = mir_eval.separation.bss_eval_sources(label_voice_signals[i, 0].cpu().numpy(), data[i].cpu().numpy(), compute_permutation=False)
    #output_sdr, output_sir, output_sar, output_perm = mir_eval.separation.bss_eval_sources(label_voice_signals[i, 0].cpu().numpy(), output_voices[i].cpu().numpy(), compute_permutation=False)
    #print("idx {} input SDR {} output SDR {}".format(i, input_sdr, output_sdr))
# Out:
# torch.Size([4, 6, 66150])
# torch.Size([4, 1, 6, 66150])
# ----------------
# idx 0 loss 0.013256090693175793
# 0.046363764
# 0.032007102
# ----------------
# idx 1 loss 0.006551437545567751
# 0.022979785
# 0.027879791
# ----------------
# idx 2 loss 0.005523230414837599
# 0.044846646
# 0.047858536
# ----------------
# idx 3 loss 0.005829179659485817
# 0.031153252
# 0.030930676
# ----------------
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-0f011bad4f2a> in <module>
#       4     print("----------------")
#       5     #print(type_name[i])
# ----> 6     print("idx {} loss {}".format(i, model.voice_loss(output_voices[i], label_voice_signals[i, 0])[0]))
#       7     print(label_voice_signals[i,:,:].cpu().detach().numpy().std())
#       8     print(output_voices[i,:,:].cpu().detach().numpy().std())
#
# IndexError: index 4 is out of bounds for dimension 0 with size 4

# %%
idx = 3
inputs = data[idx,:,:].cpu().detach().numpy()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
voice_positions = locs_voice[idx].numpy()

print(target_pos[idx])
fig, ax = plt.subplots()
ax.set(xlim=(-5, 5), ylim = (-5, 5))
ax.set_aspect("equal")
ax.axhline()
ax.axvline()

print(voice_positions)
for i in range(4):
    if voice_positions[i][0] != 0.0:
        a_circle = plt.Circle((voice_positions[i][0], voice_positions[i][1]), 0.3, color='b', fill=False)
        ax.add_artist(a_circle)
# plt.show()
# Out:
# tensor([ 0.0981, -1.9976], dtype=torch.float64)
# [[ 0.15672238  1.7385705 ]
#  [ 0.16642287  1.2554944 ]
#  [ 0.0866598  -2.974664  ]
#  [ 4.1655793  -1.0953898 ]]

# %%
label_voices = label_voice_signals[idx,0,:].cpu().detach().numpy()

# %%
output_voice_signals = output_voices[idx,:,:].cpu().detach().numpy()
print(label_voices.shape)
print(label_voices[0].std())
# Out:
# (6, 66150)
# 0.031124463

# %%
ipd.Audio(data=(inputs[[0, 3]]), rate=SAMPLE_RATE, normalize=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(data=(label_voices[[0,3]]), rate=SAMPLE_RATE, normalize=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(data=output_voice_signals[[0,3]], rate=SAMPLE_RATE, normalize=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def correlations(data):
    correlations = []
    for offset in range(-100, 100, 1):
        correlation = np.mean((np.roll(data[0], offset) - data[1])**2)
        correlations.append(correlation)
    return np.argmin(correlations)

# %%
ipd.Audio(data=(output_bg_signals[0]), rate=22050, normalize=True)

# %%
from librosa.core import stft, istft
from librosa.display import specshow

# %%
y = inputs[0]

# %%
D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=1.0)
plt.figure(figsize=(16, 8), dpi=300)
plt.subplot(1, 2, 1)
specshow(D, y_axis='linear', cmap=cm.jet)
plt.colorbar(format='%+2.0f dB')
plt.title('Linear-frequency power spectrogram')
plt.subplot(1, 2, 2)
specshow(D, y_axis='log', cmap=cm.jet)
plt.colorbar(format='%+2.0f dB')
plt.title('Log-frequency power spectrogram')
plt.plot()

# %%
y = output_voice_signals.mean(0)

# %%
D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=1.0)
plt.figure(figsize=(16, 8), dpi=300)
plt.subplot(1, 2, 1)
specshow(D, y_axis='linear', cmap=cm.jet)
plt.colorbar(format='%+2.0f dB')
plt.title('Linear-frequency power spectrogram')
plt.subplot(1, 2, 2)
specshow(D, y_axis='log', cmap=cm.jet)
plt.colorbar(format='%+2.0f dB')
plt.title('Log-frequency power spectrogram')
plt.plot()

# %%
y = label_voices[0]

# %%
D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=1.0)
plt.figure(figsize=(16, 8), dpi=300)
plt.subplot(1, 2, 1)
specshow(D, y_axis='linear', cmap=cm.jet)
plt.colorbar(format='%+2.0f dB')
plt.title('Linear-frequency power spectrogram')
plt.subplot(1, 2, 2)
specshow(D, y_axis='log', cmap=cm.jet)
plt.colorbar(format='%+2.0f dB')
plt.title('Log-frequency power spectrogram')
plt.plot()

# %%
plt.figure(figsize=(8,6), dpi=300)
counts, bins = np.histogram(D, bins=30)
plt.hist(bins[:-1], bins, weights=counts)
plt.ylim([1, 1e5])
plt.yscale('log')
plt.ylabel('count')
plt.xlabel('dB')
plt.title('Histogram')
plt.plot()

# %%
Y = stft(y)
plt.plot(np.sum(np.abs(Y), axis=1))

# %%
Y[:2, :] = 0
plt.plot(np.sum(np.abs(Y), axis=1))

# %%
Y[np.where(np.sum(np.abs(Y), axis=1) >= 10), :] = 0
plt.plot(np.sum(np.abs(Y), axis=1))

# %%
# Y = librosa.util.normalize(Y)

# %%
plt.plot(istft(Y))

# %%
D = librosa.amplitude_to_db(np.abs(Y), ref=1.0)
librosa.display.specshow(D, y_axis='log', cmap=cm.jet)
plt.colorbar(format='%+2.0f dB')
plt.title('Log-frequency power spectrogram')

# %%
newy = istft(Y)

# %%
D = librosa.amplitude_to_db(np.abs(librosa.stft(newy)), ref=1.0)
plt.figure(figsize=(16, 8), dpi=300)
plt.subplot(1, 2, 1)
librosa.display.specshow(D, y_axis='linear', cmap=cm.jet)
plt.colorbar(format='%+2.0f dB')
plt.title('Linear-frequency power spectrogram')
plt.subplot(1, 2, 2)
librosa.display.specshow(D, y_axis='log', cmap=cm.jet)
plt.colorbar(format='%+2.0f dB')
plt.title('Log-frequency power spectrogram')
plt.plot()

# %%
plt.figure(figsize=(8,6), dpi=300)
counts, bins = np.histogram(D, bins=30)
plt.hist(bins[:-1], bins, weights=counts)
plt.ylim([1, 1e5])
plt.yscale('log')
plt.ylabel('count')
plt.xlabel('dB')
plt.title('Histogram')
plt.plot()

# %%
y_gt = label_voices[0]
D = librosa.amplitude_to_db(np.abs(librosa.stft(y_gt)), ref=1.0)
plt.figure(figsize=(16, 8), dpi=300)
plt.subplot(1, 2, 1)
librosa.display.specshow(D, y_axis='linear', cmap=cm.jet)
plt.colorbar(format='%+2.0f dB')
plt.title('Linear-frequency power spectrogram')
plt.subplot(1, 2, 2)
librosa.display.specshow(D, y_axis='log', cmap=cm.jet)
plt.colorbar(format='%+2.0f dB')
plt.title('Log-frequency power spectrogram')
plt.plot()

# %%
plt.figure(figsize=(8,6), dpi=300)
counts, bins = np.histogram(D, bins=30)
plt.hist(bins[:-1], bins, weights=counts)
plt.ylim([1, 1e5])
plt.yscale('log')
plt.ylabel('count')
plt.xlabel('dB')
plt.title('Histogram')
plt.plot()

# %%
x = data[0][1].cpu().numpy()

# %%
ipd.Audio(data=(newy), rate=22050)

# %%
ipd.Audio(data=(labels[3]), rate=22050)

# %%
ipd.Audio(data=(newy), rate=22050)

# %%
top = np.sum(librosa.util.normalize(outputs[0]) ** 2) / outputs[0].shape[0]
bottom = np.sum(librosa.util.normalize(labels[0]) ** 2) / labels[0].shape[0]

# %%
SDR = 10 * np.log10(top / bottom)

# %%
print(SDR)

# %%
binaural = False
if outputs.shape[0] == 2:
    binaural = True

# %%
import os
base_dir = 'jan24'
os.makedirs(base_dir, exist_ok=True)

# %%
if not binaural:
    for i in range(outputs.shape[0]):
        librosa.output.write_wav('{}/input_{}.wav'.format(base_dir, i), inputs[i], sr=22050)
        librosa.output.write_wav('{}/output_{}.wav'.format(base_dir, i), 100 * outputs[i], sr=22050)
        librosa.output.write_wav('{}/label_{}.wav'.format(base_dir, i), labels[i], sr=22050)
else:
    librosa.output.write_wav('{}/input.wav'.format(base_dir, i), np.asfortranarray(np.vstack(inputs)), sr=22050)
    librosa.output.write_wav('{}/output.wav'.format(base_dir, i), np.asfortranarray(np.vstack(outputs)), sr=22050)
    librosa.output.write_wav('{}/label.wav'.format(base_dir, i), np.asfortranarray(np.vstack(labels)), sr=22050)

# %% [markdown]
# 233 => 1.121
# 150 => 1.835
# 100 => 1.036
# 50 => 0.648
